# %% [markdown]
# 1.What is the difference between a function and a method in Python ?
#
# Ans:A function is a block of reusable code that performs a specific task and is not associated with any class or object.
#
# A method is a function that is associated with an object and defined inside a class.

# %% [markdown]
# 2.Explain the concept of function arguments and parameters in Python.
#
# Ans:Parameters are the variables written inside the function definition.
#
# Arguments are the actual values passed to the function when it is called.

# %% [markdown]
# 3. What are the different ways to define and call a function in Python?
#
# Ans:
# Normal function--> A function defined using the def keyword and called directly.
#
# Function with return statement --> Function that returns a value using return.
#
# Lambda function -->A function without a name, written in one line.
#
# there are many other types of functions also like default value function , recursive function ,function with variable arguments etc.

# %% [markdown]
# 4.What is the purpose of the `return` statement in a Python function?
#
# Ans:The return statement is used to send a value from a function back to the place where it was called and terminate the function execution.

# %% [markdown]
# 5. What are iterators in Python and how do they differ from iterables?
#
# Ans:An iterable is any Python object that can be looped over (iterated) using a for loop.
#
# An iterator is an object that produces values one at a time using the __next__() method.

# %% [markdown]
# 6. Explain the concept of generators in Python and how they are defined.
#
# Ans:A generator in Python is a special type of function that returns an iterator and produces values one at a time using the yield keyword instead of return.

# %% [markdown]
# 7. What are the advantages of using generators over regular functions?
#
# Ans: Memory Efficiency (Most Important Advantage)
# Explanation
#
# Regular functions store the entire result in memory
#
# Generators store only one value at a time.
#
# Generators produce values only when requested using next() or a loop.

# %% [markdown]
# 8.What is a lambda function in Python and when is it typically used?
#
# Ans:A lambda function in Python is a small, anonymous function (a function without a name) that is defined using the lambda keyword.
#
# It can take any number of arguments but contains only one expression.

# %% [markdown]
# 9.Explain the purpose and usage of the `map()` function in Python.
#
# Ans:The map() function in Python is a built-in higher-order function that applies a given function to each element of an iterable (like a list, tuple, etc.) and returns a map object.

# %% [markdown]
# 10.What is the difference between `map()`, `reduce()`, and `filter()` functions in Python?
# Ans:The map() function is used to apply a function to each element of an iterable and return the transformed results.
#
# The filter() function is used to select elements from an iterable that satisfy a given condition.
#
# The reduce() function is used to reduce an iterable to a single value by repeatedly applying a function.

# %% [markdown]
# 11. Using pen & Paper write the internal mechanism for sum operation using  reduce function on this given
# list:[47,11,42,13];
# ![image1.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![image2.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# #PRACTICAL QUESTIONS->

# %%
#1. Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in
#the list.

def sum(lis):
  total=0
  for i in lis:
    if i%2==0:
      total+=i
  return total

# %%
numbers=list(map(int,input("enter the elements of list separated by space: ").split()))
result=sum(numbers)
print(result)
# Out:
# enter the elements of list separated by space: 1 2 3 4 5 6 6
# 18

# %%
# 2. Create a Python function that accepts a string and returns the reverse of that string.
def rev(s):
  reverse=""
  for ch in s:
    reverse=ch+reverse
  return reverse

# %%
word="Python"
result=rev(word)
print(result)
# Out:
# nohtyP

# %%
# 3. Implement a Python function that takes a list of integers and returns a new list containing the squares of each number.
def square_list(a):
  squares=[]
  for i in a:
    squares.append(i**2)
  return squares

# %%
s=square_list([2,3,4,5,6])
print(s)
# Out:
# [4, 9, 16, 25, 36]

# %%
# 4. Write a Python function that checks if a given number is prime or not from 1 to 200.
def prime_no(n):
  if n<2:
    return "it is not a prime number"
  for i in range(2,n):
      if n%i==0:
        return "it is not a prime number"
  return "it is a prime number"

# %%
result=prime_no(4)
print(result)
# Out:
# it is not a prime number

# %%
# 5. Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of terms.

class Fibonacci:
    def __init__(self, n):
        self.n = n
        self.a = 0
        self.b = 1
        self.count = 0

    def __iter__(self):
        return self

    def __next__(self):
        if self.count == self.n:
            raise StopIteration

        value = self.a
        self.a = self.b
        self.b = value + self.b
        self.count += 1
        return value

for num in Fibonacci(5):
    print(num)
# Out:
# 0
# 1
# 1
# 2
# 3

# %%
# 6. Write a generator function in Python that yields the powers of 2 up to a given exponent.
def power_of_2(n):
  for i in range(n+1):
    yield 2**i

# %%
exp=int(input("Enter exponent:"))
for value in power_of_2(exp):
  print(value)
# Out:
# Enter exponent:5
# 1
# 2
# 4
# 8
# 16
# 32

# %%
# 8. Use a lambda function in Python to sort a list of tuples based on the second element of each tuple.
data = [(1, 3), (4, 1), (2, 2), (5, 0)]
data.sort(key=lambda x: x[1])

print(data)
# Out:
# [(5, 0), (4, 1), (2, 2), (1, 3)]

# %%
#9. Write a Python program that uses `map()` to convert a list of temperatures from Celsius to Fahrenheit.
celsius = [0, 10, 20, 30, 40]
fahrenheit = list(map(lambda c: (c * 9/5) + 32, celsius))

print(fahrenheit)
# Out:
# [32.0, 50.0, 68.0, 86.0, 104.0]

# %%
#10. Create a Python program that uses `filter()` to remove all the vowels from a given string.
text = "Hello Python"

vowels = "aeiouAEIOU"
result = filter(lambda ch: ch not in vowels, text)

# print each character
for ch in result:
    print(ch, end="")
# Out:
# Hll Pythn

# %%
# 11
orders = [
    (34587, "Learning Python", 4, 40.95),
    (98762, "Programming Python", 5, 56.80),
    (77226, "Head First Python", 3, 32.95),
    (88112, "Einführung in Python3", 3, 24.99)
]

print(list(map(lambda o: (o[0], o[2]*o[3] + 10 if o[2]*o[3] < 100 else o[2]*o[3]), orders)))
# Out:
# [(34587, 163.8), (98762, 284.0), (77226, 108.85000000000001), (88112, 84.97)]
